# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
data = pd.read_csv('C:/Users/user/Desktop/Car_sales.csv')

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# ***# Question 1. Identify the variable types in the given data set.***

# %%
data.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %% [markdown]
# ***# Question 2. Make a bar graph for manufacturer type.***

# %%
Manufacturer_counts = data['Manufacturer'].value_counts()
plt.bar(Manufacturer_counts.index, Manufacturer_counts)
plt.xticks(rotation=90)
plt.xlabel('Manufacturer')
plt.ylabel('Count')
plt.title('Manufacturer Type Distribution')
plt.figure(figsize=(10, 6))
plt.show()

# %% [markdown]
# ***# Question 3. Make a pie chart for showing vehicle type by percentage.***

# %%
vehicle_type_counts = data['Vehicle_type'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(vehicle_type_counts, labels=vehicle_type_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Vehicle Type Distribution')
plt.show()

# %% [markdown]
# ***# Question 4. Calculate average Price of all cars by using correct measure of central Tendency.***

# %%
average_price = data['Price_in_thousands'].mean()

print(f"The average price of all cars in thousands is: {average_price:.2f} Thousands")
# Out:
# The average price of all cars in thousands is: 27.39 Thousands

# %% [markdown]
# ***# Question 5. Calculate the variance and standard deviation for numerical columns such as Sales_in_thousands, __year_resale_value, Price_in_thousands, Engine_size, Horsepower.***

# %%
numerical_columns = ['Sales_in_thousands', '__year_resale_value', 'Price_in_thousands', 'Engine_size', 'Horsepower']
variances = data[numerical_columns].var()
std_devs = data[numerical_columns].std()

print("Variance:")
print(variances)

print("\nStandard Deviation:")
print(std_devs)
# Out:
# Variance:
# Sales_in_thousands     4628.002257
# __year_resale_value     131.180007
# Price_in_thousands      205.969949
# Engine_size               1.091300
# Horsepower             3214.926385
# dtype: float64
#
# Standard Deviation:
# Sales_in_thousands     68.029422
# __year_resale_value    11.453384
# Price_in_thousands     14.351653
# Engine_size             1.044653
# Horsepower             56.700321
# dtype: float64

# %% [markdown]
# ***# Question 6.For the same columns Calculate IQR and identify outliers in these columns
# Q1 = df[column].quantile(0.25)
# Q3 = df[column].quantile(0.75)
# IQR = Q3 - Q1
# outliers = df[(df[column] &lt; Q1 - 1.5 * IQR) | (df[column] &gt; Q3 + 1.5 * IQR)]***

# %%
for column in numerical_columns:
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1

    outliers = data[(data[column] < Q1 - 1.5 * IQR) | (data[column] > Q3 + 1.5 * IQR)]

    print(f"\nOutliers for {column}:")
    print(outliers)
# Out:
# Outliers for Sales_in_thousands:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 40         Dodge      Ram Pickup             227.061               15.060
# 45         Dodge         Caravan             181.749               12.025
# 49          Ford          Taurus             245.815               10.055
# 50          Ford           Focus             175.670                  NaN
# 52          Ford        Explorer             276.747               16.640
# 53          Ford        Windstar             155.787               13.175
# 55          Ford          Ranger             220.650                7.850
# 56          Ford        F-Series             540.561               15.075
# 57         Honda           Civic             199.685                9.850
# 58         Honda          Accord             230.902               13.210
# 69          Jeep  Grand Cherokee             157.040               18.810
# ...

# %% [markdown]
# ***# Question 7. Make Histograms for all Numerical columns and identify the distribution of type by calculating
# skewness;
# Note : If the skewness is 0, it indicates a perfectly symmetrical distribution.
# If the skewness is negative, it means the distribution is skewed to the left (long left tail).
# If the skewness is positive, it means the distribution is skewed to the right (long right tail).***

# %%
import matplotlib.pyplot as plt
from scipy.stats import skew

for column in numerical_columns:
    plt.figure(figsize=(8, 6))
    plt.hist(data[column], edgecolor='black')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

    skewness = skew(data[column])
    print(f"Skewness for {column}: {skewness}")

    if skewness == 0:
        print("The distribution is perfectly symmetrical.")
    elif skewness < 0:
        print("The distribution is skewed to the left (long left tail).")
    else:
        print("The distribution is skewed to the right (long right tail).")
# Out:
# Skewness for Sales_in_thousands: 3.375866090661253
# The distribution is skewed to the right (long right tail).
# Skewness for __year_resale_value: nan
# The distribution is skewed to the right (long right tail).
# Skewness for Price_in_thousands: nan
# The distribution is skewed to the right (long right tail).
# Skewness for Engine_size: nan
# The distribution is skewed to the right (long right tail).
# Skewness for Horsepower: nan
# The distribution is skewed to the right (long right tail).
